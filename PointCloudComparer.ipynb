# %%
import os
import csv
import numpy as np
from plyfile import PlyData
from scipy.spatial.distance import directed_hausdorff

class PointCloudComparer:
    def __init__(self, sample_dir, output_dir):
        self.sample_dir = sample_dir
        self.output_dir = output_dir

    def load_pointcloud(self, dir, filename):
        plydata = PlyData.read(os.path.join(dir, filename))
        pc = np.vstack([plydata['vertex']['x'], plydata['vertex']['y'], plydata['vertex']['z']]).T
        return pc

    def get_binary_image(self, pc, axes, min_coordinates, max_coordinates):
        pc_rounded = np.round(pc[:, axes]).astype(int)
        pc_shifted = pc_rounded - min_coordinates
        shape = max_coordinates - min_coordinates + 1
        img = np.zeros(shape)
        img[pc_shifted[:,0], pc_shifted[:,1]] = 1  # y first, then x
        return img

    def compute_metrics(self, img1_bin, img2_bin):
        # Compute pixel accuracy
        pixel_accuracy = np.sum(img1_bin == img2_bin) / np.prod(img1_bin.shape)

        # Compute Intersection over Union (IoU)
        intersection = np.logical_and(img1_bin, img2_bin)
        union = np.logical_or(img1_bin, img2_bin)
        iou = np.sum(intersection) / np.sum(union)

        # Compute Dice Similarity Coefficient (DSC)
        dsc = 2 * np.sum(intersection) / (np.sum(img1_bin) + np.sum(img2_bin))

        # Compute Mean Squared Error (MSE)
        mse = np.sum((img1_bin - img2_bin) ** 2) / np.prod(img1_bin.shape)

        return pixel_accuracy, iou, dsc, mse

    def process_group(self, group_number):
        metrics = {}
        pc1 = self.load_pointcloud(self.sample_dir, f"T{group_number}_M.ply")
        pc2 = self.load_pointcloud(self.sample_dir, f"T{group_number}_T.ply")

        # Ensure that both point clouds are 3D
        pc1 = pc1[:, :3]
        pc2 = pc2[:, :3]

        views = [('front', [0, 1]), ('side', [1, 2]), ('top', [0, 2])]

        for view, axes in views:
            pc1_rounded = np.round(pc1[:, axes]).astype(int)
            pc2_rounded = np.round(pc2[:, axes]).astype(int)

            min_coordinates = np.min(np.vstack([pc1_rounded, pc2_rounded]), axis=0)
            max_coordinates = np.max(np.vstack([pc1_rounded, pc2_rounded]), axis=0)

            img1_bin = self.get_binary_image(pc1, axes, min_coordinates, max_coordinates)
            img2_bin = self.get_binary_image(pc2, axes, min_coordinates, max_coordinates)

            pixel_accuracy, iou, dsc, mse = self.compute_metrics(img1_bin, img2_bin)

            metrics[f"{view}_pixel_accuracy"] = pixel_accuracy
            metrics[f"{view}_IoU"] = iou
            metrics[f"{view}_DSC"] = dsc
            metrics[f"{view}_MSE"] = mse

        hausdorff_distance = directed_hausdorff(pc1, pc2)[0]
        metrics["Hausdorff_distance"] = hausdorff_distance

        min_coordinates = np.min(np.vstack([pc1, pc2]), axis=0)
        max_coordinates = np.max(np.vstack([pc1, pc2]), axis=0)
        diagonal_length = np.linalg.norm(max_coordinates - min_coordinates)
        normalized_hausdorff_distance = hausdorff_distance / diagonal_length
        metrics["Normalized_Hausdorff_distance"] = normalized_hausdorff_distance

        return metrics

    def process_all(self, total_samples):
        header = ["sample", "front_pixel_accuracy", "front_IoU", "front_DSC", "front_MSE",
                  "side_pixel_accuracy", "side_IoU", "side_DSC", "side_MSE",
                  "top_pixel_accuracy", "top_IoU", "top_DSC", "top_MSE",
                  "Hausdorff_distance", "Normalized_Hausdorff_distance"]
        with open(os.path.join(self.output_dir, "results.csv"), "w", newline='') as file:
            writer = csv.writer(file)
            writer.writerow(header)

            for i in range(148, 148 + total_samples):
                print(f"Processing sample T{i}...")
                metrics = self.process_group(i)
                row = [f'T{i}'] + [metrics[metric] for metric in header[1:]]
                writer.writerow(row)

# %%
# Define the directories
sample_dir = "E:\A files\Master\Dissertation\Samples\MLA01\MLA01_ply"
output_dir = "E:\A files\Master\Dissertation\Samples\MLA01"

# Initialize and run the comparer
total_samples = 147
comparer = PointCloudComparer(sample_dir, output_dir)
comparer.process_all(total_samples)
# Out:
# Processing sample T1...
# Processing sample T2...
# Processing sample T3...
# Processing sample T4...
# Processing sample T5...
# Processing sample T6...
# Processing sample T7...
# Processing sample T8...
# Processing sample T9...
# Processing sample T10...
# Processing sample T11...
# Processing sample T12...
# Processing sample T13...
# Processing sample T14...
# Processing sample T15...
# Processing sample T16...
# Processing sample T17...
# Processing sample T18...
# Processing sample T19...
# Processing sample T20...
# Processing sample T21...
# Processing sample T22...
# Processing sample T23...
# Processing sample T24...
# Processing sample T25...
# Processing sample T26...
# Processing sample T27...
# Processing sample T28...
# Processing sample T29...
# Processing sample T30...
# Processing sample T31...
# Processing sample T32...
# Processing sample T33...
# Processing sample T34...
# Processing sample T35...
# Processing sample T36...
# Processing sample T37...
# Processing sample T38...
# Processing sample T39...
# Processing sample T40...
# Processing sample T41...
# Processing sample T42...
# Processing sample T43...
# Processing sample T44...
# Processing sample T45...
# Processing sample T46...
# Processing sample T47...
# Processing sample T48...
# Processing sample T49...
# Processing sample T50...
# Processing sample T51...
# Processing sample T52...
# Processing sample T53...
# Processing sample T54...
# Processing sample T55...
# Processing sample T56...
# Processing sample T57...
# Processing sample T58...
# Processing sample T59...
# Processing sample T60...
# Processing sample T61...
# Processing sample T62...
# Processing sample T63...
# Processing sample T64...
# Processing sample T65...
# Processing sample T66...
# Processing sample T67...
# Processing sample T68...
# Processing sample T69...
# Processing sample T70...
# Processing sample T71...
# Processing sample T72...
# Processing sample T73...
# Processing sample T74...
# Processing sample T75...
# Processing sample T76...
# Processing sample T77...
# Processing sample T78...
# Processing sample T79...
# Processing sample T80...
# Processing sample T81...
# Processing sample T82...
# Processing sample T83...
# Processing sample T84...
# Processing sample T85...
# Processing sample T86...
# Processing sample T87...
# Processing sample T88...
# Processing sample T89...
# Processing sample T90...
# Processing sample T91...
# Processing sample T92...
# Processing sample T93...
# Processing sample T94...
# Processing sample T95...
# Processing sample T96...
# Processing sample T97...
# Processing sample T98...
# Processing sample T99...
# Processing sample T100...
# Processing sample T101...
# Processing sample T102...
# Processing sample T103...
# Processing sample T104...
# Processing sample T105...
# Processing sample T106...
# Processing sample T107...
# Processing sample T108...
# Processing sample T109...
# Processing sample T110...
# Processing sample T111...
# Processing sample T112...
# Processing sample T113...
# Processing sample T114...
# Processing sample T115...
# Processing sample T116...
# Processing sample T117...
# Processing sample T118...
# Processing sample T119...
# Processing sample T120...
# Processing sample T121...
# Processing sample T122...
# Processing sample T123...
# Processing sample T124...
# Processing sample T125...
# Processing sample T126...
# Processing sample T127...
# Processing sample T128...
# Processing sample T129...
# Processing sample T130...
# Processing sample T131...
# Processing sample T132...
# Processing sample T133...
# Processing sample T134...
# Processing sample T135...
# Processing sample T136...
# Processing sample T137...
# Processing sample T138...
# Processing sample T139...
# Processing sample T140...
# Processing sample T141...
# Processing sample T142...
# Processing sample T143...
# Processing sample T144...
# Processing sample T145...
# Processing sample T146...
# Processing sample T147...

# %%
# Define the directories
sample_dir = "E:\A files\Master\Dissertation\Samples\WYT\WYT_ply"
output_dir = "E:\A files\Master\Dissertation\Samples\WYT"

# Initialize and run the comparer
total_samples = 344
comparer = PointCloudComparer(sample_dir, output_dir)
comparer.process_all(total_samples)
# Out:
# Processing sample T148...
# Processing sample T149...
# Processing sample T150...
# Processing sample T151...
# Processing sample T152...
# Processing sample T153...
# Processing sample T154...
# Processing sample T155...
# Processing sample T156...
# Processing sample T157...
# Processing sample T158...
# Processing sample T159...
# Processing sample T160...
# Processing sample T161...
# Processing sample T162...
# Processing sample T163...
# Processing sample T164...
# Processing sample T165...
# Processing sample T166...
# Processing sample T167...
# Processing sample T168...
# Processing sample T169...
# Processing sample T170...
# Processing sample T171...
# Processing sample T172...
# Processing sample T173...
# Processing sample T174...
# Processing sample T175...
# Processing sample T176...
# Processing sample T177...
# Processing sample T178...
# Processing sample T179...
# Processing sample T180...
# Processing sample T181...
# Processing sample T182...
# Processing sample T183...
# Processing sample T184...
# Processing sample T185...
# Processing sample T186...
# Processing sample T187...
# Processing sample T188...
# Processing sample T189...
# Processing sample T190...
# Processing sample T191...
# Processing sample T192...
# Processing sample T193...
# Processing sample T194...
# Processing sample T195...
# Processing sample T196...
# Processing sample T197...
# Processing sample T198...
# Processing sample T199...
# Processing sample T200...
# Processing sample T201...
# Processing sample T202...
# Processing sample T203...
# Processing sample T204...
# Processing sample T205...
# Processing sample T206...
# Processing sample T207...
# Processing sample T208...
# Processing sample T209...
# Processing sample T210...
# Processing sample T211...
# Processing sample T212...
# Processing sample T213...
# Processing sample T214...
# Processing sample T215...
# Processing sample T216...
# Processing sample T217...
# Processing sample T218...
# Processing sample T219...
# Processing sample T220...
# Processing sample T221...
# Processing sample T222...
# Processing sample T223...
# Processing sample T224...
# Processing sample T225...
# Processing sample T226...
# Processing sample T227...
# Processing sample T228...
# Processing sample T229...
# Processing sample T230...
# Processing sample T231...
# Processing sample T232...
# Processing sample T233...
# Processing sample T234...
# Processing sample T235...
# Processing sample T236...
# Processing sample T237...
# Processing sample T238...
# Processing sample T239...
# Processing sample T240...
# Processing sample T241...
# Processing sample T242...
# Processing sample T243...
# Processing sample T244...
# Processing sample T245...
# Processing sample T246...
# Processing sample T247...
# Processing sample T248...
# Processing sample T249...
# Processing sample T250...
# Processing sample T251...
# Processing sample T252...
# Processing sample T253...
# Processing sample T254...
# Processing sample T255...
# Processing sample T256...
# Processing sample T257...
# Processing sample T258...
# Processing sample T259...
# Processing sample T260...
# Processing sample T261...
# Processing sample T262...
# Processing sample T263...
# Processing sample T264...
# Processing sample T265...
# Processing sample T266...
# Processing sample T267...
# Processing sample T268...
# Processing sample T269...
# Processing sample T270...
# Processing sample T271...
# Processing sample T272...
# Processing sample T273...
# Processing sample T274...
# Processing sample T275...
# Processing sample T276...
# Processing sample T277...
# Processing sample T278...
# Processing sample T279...
# Processing sample T280...
# Processing sample T281...
# Processing sample T282...
# Processing sample T283...
# Processing sample T284...
# Processing sample T285...
# Processing sample T286...
# Processing sample T287...
# Processing sample T288...
# Processing sample T289...
# Processing sample T290...
# Processing sample T291...
# Processing sample T292...
# Processing sample T293...
# Processing sample T294...
# Processing sample T295...
# Processing sample T296...
# Processing sample T297...
# Processing sample T298...
# Processing sample T299...
# Processing sample T300...
# Processing sample T301...
# Processing sample T302...
# Processing sample T303...
# Processing sample T304...
# Processing sample T305...
# Processing sample T306...
# Processing sample T307...
# Processing sample T308...
# Processing sample T309...
# Processing sample T310...
# Processing sample T311...
# Processing sample T312...
# Processing sample T313...
# Processing sample T314...
# Processing sample T315...
# Processing sample T316...
# Processing sample T317...
# Processing sample T318...
# Processing sample T319...
# Processing sample T320...
# Processing sample T321...
# Processing sample T322...
# Processing sample T323...
# Processing sample T324...
# Processing sample T325...
# Processing sample T326...
# Processing sample T327...
# Processing sample T328...
# Processing sample T329...
# Processing sample T330...
# Processing sample T331...
# Processing sample T332...
# Processing sample T333...
# Processing sample T334...
# Processing sample T335...
# Processing sample T336...
# Processing sample T337...
# Processing sample T338...
# Processing sample T339...
# Processing sample T340...
# Processing sample T341...
# Processing sample T342...
# Processing sample T343...
# Processing sample T344...
# Processing sample T345...
# Processing sample T346...
# Processing sample T347...
# Processing sample T348...
# Processing sample T349...
# Processing sample T350...
# Processing sample T351...
# Processing sample T352...
# Processing sample T353...
# Processing sample T354...
# Processing sample T355...
# Processing sample T356...
# Processing sample T357...
# Processing sample T358...
# Processing sample T359...
# Processing sample T360...
# Processing sample T361...
# Processing sample T362...
# Processing sample T363...
# Processing sample T364...
# Processing sample T365...
# Processing sample T366...
# Processing sample T367...
# Processing sample T368...
# Processing sample T369...
# Processing sample T370...
# Processing sample T371...
# Processing sample T372...
# Processing sample T373...
# Processing sample T374...
# Processing sample T375...
# Processing sample T376...
# Processing sample T377...
# Processing sample T378...
# Processing sample T379...
# Processing sample T380...
# Processing sample T381...
# Processing sample T382...
# Processing sample T383...
# Processing sample T384...
# Processing sample T385...
# Processing sample T386...
# Processing sample T387...
# Processing sample T388...
# Processing sample T389...
# Processing sample T390...
# Processing sample T391...
# Processing sample T392...
# Processing sample T393...
# Processing sample T394...
# Processing sample T395...
# Processing sample T396...
# Processing sample T397...
# Processing sample T398...
# Processing sample T399...
# Processing sample T400...
# Processing sample T401...
# Processing sample T402...
# Processing sample T403...
# Processing sample T404...
# Processing sample T405...
# Processing sample T406...
# Processing sample T407...
# Processing sample T408...
# Processing sample T409...
# Processing sample T410...
# Processing sample T411...
# Processing sample T412...
# Processing sample T413...
# Processing sample T414...
# Processing sample T415...
# Processing sample T416...
# Processing sample T417...
# Processing sample T418...
# Processing sample T419...
# Processing sample T420...
# Processing sample T421...
# Processing sample T422...
# Processing sample T423...
# Processing sample T424...
# Processing sample T425...
# Processing sample T426...
# Processing sample T427...
# Processing sample T428...
# Processing sample T429...
# Processing sample T430...
# Processing sample T431...
# Processing sample T432...
# Processing sample T433...
# Processing sample T434...
# Processing sample T435...
# Processing sample T436...
# Processing sample T437...
# Processing sample T438...
# Processing sample T439...
# Processing sample T440...
# Processing sample T441...
# Processing sample T442...
# Processing sample T443...
# Processing sample T444...
# Processing sample T445...
# Processing sample T446...
# Processing sample T447...
# Processing sample T448...
# Processing sample T449...
# Processing sample T450...
# Processing sample T451...
# Processing sample T452...
# Processing sample T453...
# Processing sample T454...
# Processing sample T455...
# Processing sample T456...
# Processing sample T457...
# Processing sample T458...
# Processing sample T459...
# Processing sample T460...
# Processing sample T461...
# Processing sample T462...
# Processing sample T463...
# Processing sample T464...
# Processing sample T465...
# Processing sample T466...
# Processing sample T467...
# Processing sample T468...
# Processing sample T469...
# Processing sample T470...
# Processing sample T471...
# Processing sample T472...
# Processing sample T473...
# Processing sample T474...
# Processing sample T475...
# Processing sample T476...
# Processing sample T477...
# Processing sample T478...
# Processing sample T479...
# Processing sample T480...
# Processing sample T481...
# Processing sample T482...
# Processing sample T483...
# Processing sample T484...
# Processing sample T485...
# Processing sample T486...
# Processing sample T487...
# Processing sample T488...
# Processing sample T489...
# Processing sample T490...
# Processing sample T491...
# Processing sample T492...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 8
#       6 total_samples = 344
#       7 comparer = PointCloudComparer(sample_dir, output_dir)
# ----> 8 comparer.process_all(total_samples)
#
# Cell In[3], line 92, in PointCloudComparer.process_all(self, total_samples)
#      90 for i in range(148, 148 + total_samples + 1):
#      91     print(f"Processing sample T{i}...")
# ---> 92     metrics = self.process_group(i)
#      93     row = [f'T{i}'] + [metrics[metric] for metric in header[1:]]
#      94     writer.writerow(row)
#
# Cell In[3], line 44, in PointCloudComparer.process_group(self, group_number)
#      42 def process_group(self, group_number):
#      43     metrics = {}
# ---> 44     pc1 = self.load_pointcloud(self.sample_dir, f"T{group_number}_M.ply")
#      45     pc2 = self.load_pointcloud(self.sample_dir, f"T{group_number}_T.ply")
#      47     # Ensure that both point clouds are 3D
#
# Cell In[3], line 13, in PointCloudComparer.load_pointcloud(self, dir, filename)
#      12 def load_pointcloud(self, dir, filename):
# ---> 13     plydata = PlyData.read(os.path.join(dir, filename))
#      14     pc = np.vstack([plydata['vertex']['x'], plydata['vertex']['y'], plydata['vertex']['z']]).T
#      15     return pc
#
# File c:\Users\Albert\.conda\envs\pytorch\lib\site-packages\plyfile.py:158, in PlyData.read(stream, mmap, known_list_len)
#     130 @staticmethod
#     131 def read(stream, mmap=True, known_list_len={}):
#     132     """
#     133     Read PLY data from a readable file-like object or filename.
#     134
#    (...)
#     156         indicates binary encoding.
#     157     """
# --> 158     (must_close, stream) = _open_stream(stream, 'read')
#     159     try:
#     160         data = PlyData._parse_header(stream)
#
# File c:\Users\Albert\.conda\envs\pytorch\lib\site-packages\plyfile.py:1345, in _open_stream(stream, read_or_write)
#    1343     return (False, stream)
#    1344 try:
# -> 1345     return (True, open(stream, read_or_write[0] + 'b'))
#    1346 except TypeError:
#    1347     raise TypeError("expected open file or filename")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'E:\\A files\\Master\\Dissertation\\Samples\\WYT\\WYT_ply\\T492_M.ply'
