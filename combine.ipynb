# %%
import open3d as o3d
import numpy as np
from pathlib import Path
from collections import defaultdict
import os

# Define the directories
input_dir = Path('E:/A files/Master/Dissertation/Samples/mla01.manual')
output_dir = Path('E:/A files/Master/Dissertation/Samples/mla01.manual_comb')

# Create output directory if not exists
output_dir.mkdir(parents=True, exist_ok=True)

# Group the files by their numbers
files_by_number = defaultdict(list)

for file in input_dir.glob('MLA01_2018_*.*.ply'):
    number = file.stem.split('_')[2].split('.')[0]  # Extract the {XXX} part
    files_by_number[number].append(file)

print(f'Found {len(files_by_number)} groups of files')

# Iterate over the grouped files
for number, files in files_by_number.items():
    if len(files) != 2:
        print(f"Skipping {number} as it does not have exactly 2 files")
        continue

    print(f'Processing files: {files[0].name}, {files[1].name}')

    # Sort files to ensure 'leaf' comes first, then 'wood'
    files = sorted(files, key=lambda x: x.stem.split('_')[2].split('.')[1])

    # Load the point clouds
    pcd1 = o3d.io.read_point_cloud(str(files[0]))
    pcd2 = o3d.io.read_point_cloud(str(files[1]))

    # Estimate the transformation for alignment with ICP
    max_correspondence_distance = 0.02  # This is a parameter you might need to adjust
    init = np.identity(4)
    transformation = o3d.pipelines.registration.registration_icp(
        pcd1, pcd2, max_correspondence_distance, init,
        o3d.pipelines.registration.TransformationEstimationPointToPoint()
    ).transformation

    # Apply the transformation to the second point cloud
    pcd2.transform(transformation)

    # Combine the point clouds
    pcd_combined = pcd1 + pcd2

    # Save the combined point cloud as a .ply file
    output_file = output_dir / f"MLA01_2018_{number}.ply"
    o3d.io.write_point_cloud(str(output_file), pcd_combined)

    print(f'Saved combined point cloud as: {output_file}')
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.
# Found 175 groups of files
# Processing files: MLA01_2018_A32.leaf.ply, MLA01_2018_A32.wood.ply
# Saved combined point cloud as: E:\A files\Master\Dissertation\Samples\mla01.manual_comb\MLA01_2018_A32.ply
# Processing files: MLA01_2018_S8.leaf.ply, MLA01_2018_S8.wood.ply
# Saved combined point cloud as: E:\A files\Master\Dissertation\Samples\mla01.manual_comb\MLA01_2018_S8.ply
# Processing files: MLA01_2018_T10.leaf.ply, MLA01_2018_T10.wood.ply
# Saved combined point cloud as: E:\A files\Master\Dissertation\Samples\mla01.manual_comb\MLA01_2018_T10.ply
# Processing files: MLA01_2018_T100.leaf.ply, MLA01_2018_T100.wood.ply
# Saved combined point cloud as: E:\A files\Master\Dissertation\Samples\mla01.manual_comb\MLA01_2018_T100.ply
# Processing files: MLA01_2018_T102.leaf.ply, MLA01_2018_T102.wood.ply
# Saved combined point cloud as: E:\A files\Master\Dissertation\Samples\mla01.manual_comb\MLA01_2018_T102.ply
# Processing files: MLA01_2018_T104.leaf.ply, MLA01_2018_T104.wood.ply
# Saved combined point cloud as: E:\A files\Master\Dissertation\Samples\mla01.manual_comb\MLA01_2018_T104.ply
# Processing files: MLA01_2018_T105.leaf.ply, MLA01_2018_T105.wood.ply
# Saved combined point cloud as: E:\A files\Master\Dissertation\Samples\mla01.manual_comb\MLA01_2018_T105.ply
# Processing files: MLA01_2018_T106.leaf.ply, MLA01_2018_T106.wood.ply
# Saved combined point cloud as: E:\A files\Master\Dissertation\Samples\mla01.manual_comb\MLA01_2018_T106.ply
# Processing files: MLA01_2018_T11.leaf.ply, MLA01_2018_T11.wood.ply
# Saved combined point cloud as: E:\A files\Master\Dissertation\Samples\mla01.manual_comb\MLA01_2018_T11.ply
# Processing files: MLA01_2018_T110.leaf.ply, MLA01_2018_T110.wood.ply
# Saved combined point cloud as: E:\A files\Master\Dissertation\Samples\mla01.manual_comb\MLA01_2018_T110.ply
# Processing files: MLA01_2018_T111.leaf.ply, MLA01_2018_T111.wood.ply
# Saved combined point cloud as: E:\A files\Master\Dissertation\Samples\mla01.manual_comb\MLA01_2018_T111.ply
# Processing files: MLA01_2018_T115.leaf.ply, MLA01_2018_T115.wood.ply
# Saved combined point cloud as: E:\A files\Master\Dissertation\Samples\mla01.manual_comb\MLA01_2018_T115.ply
# Processing files: MLA01_2018_T116.leaf.ply, MLA01_2018_T116.wood.ply
# Saved combined point cloud as: E:\A files\Master\Dissertation\Samples\mla01.manual_comb\MLA01_2018_T116.ply
# Processing files: MLA01_2018_T119.leaf.ply, MLA01_2018_T119.wood.ply
# Saved combined point cloud as: E:\A files\Master\Dissertation\Samples\mla01.manual_comb\MLA01_2018_T119.ply
# Processing files: MLA01_2018_T12.leaf.ply, MLA01_2018_T12.wood.ply
# Saved combined point cloud as: E:\A files\Master\Dissertation\Samples\mla01.manual_comb\MLA01_2018_T12.ply
# Processing files: MLA01_2018_T120.leaf.ply, MLA01_2018_T120.wood.ply
# Saved combined point cloud as: E:\A files\Master\Dissertation\Samples\mla01.manual_comb\MLA01_2018_T120.ply
# Processing files: MLA01_2018_T123.leaf.ply, MLA01_2018_T123.wood.ply
# Saved combined point cloud as: E:\A files\Master\Dissertation\Samples\mla01.manual_comb\MLA01_2018_
wood.ply
# Saved combined point cloud as: E:\A files\Master\Dissertation\Samples\mla01.manual_comb\MLA01_2018_T63.ply
# Processing files: MLA01_2018_T64.leaf.ply, MLA01_2018_T64.wood.ply
# Saved combined point cloud as: E:\A files\Master\Dissertation\Samples\mla01.manual_comb\MLA01_2018_T64.ply
# Processing files: MLA01_2018_T8.leaf.ply, MLA01_2018_T8.wood.ply
# Saved combined point cloud as: E:\A files\Master\Dissertation\Samples\mla01.manual_comb\MLA01_2018_T8.ply
# Processing files: MLA01_2018_T80.leaf.ply, MLA01_2018_T80.wood.ply
# Saved combined point cloud as: E:\A files\Master\Dissertation\Samples\mla01.manual_comb\MLA01_2018_T80.ply
# Processing files: MLA01_2018_T81.leaf.ply, MLA01_2018_T81.wood.ply
# Saved combined point cloud as: E:\A files\Master\Dissertation\Samples\mla01.manual_comb\MLA01_2018_T81.ply
# Processing files: MLA01_2018_T82.leaf.ply, MLA01_2018_T82.wood.ply
# Saved combined point cloud as: E:\A files\Master\Dissertation\Samples\mla01.manual_comb\MLA01_2018_T82.ply
# Processing files: MLA01_2018_T84.leaf.ply, MLA01_2018_T84.wood.ply
# Saved combined point cloud as: E:\A files\Master\Dissertation\Samples\mla01.manual_comb\MLA01_2018_T84.ply
# Processing files: MLA01_2018_T93.leaf.ply, MLA01_2018_T93.wood.ply
# Saved combined point cloud as: E:\A files\Master\Dissertation\Samples\mla01.manual_comb\MLA01_2018_T93.ply
# Processing files: MLA01_2018_T94.leaf.ply, MLA01_2018_T94.wood.ply
# Saved combined point cloud as: E:\A files\Master\Dissertation\Samples\mla01.manual_comb\MLA01_2018_T94.ply
# Processing files: MLA01_2018_T95.leaf.ply, MLA01_2018_T95.wood.ply
# Saved combined point cloud as: E:\A files\Master\Dissertation\Samples\mla01.manual_comb\MLA01_2018_T95.ply
# Processing files: MLA01_2018_T96.leaf.ply, MLA01_2018_T96.wood.ply
# Saved combined point cloud as: E:\A files\Master\Dissertation\Samples\mla01.manual_comb\MLA01_2018_T96.ply
# Processing files: MLA01_2018_T97.leaf.ply, MLA01_2018_T97.wood.ply
# Saved combined point cloud as: E:\A files\Master\Dissertation\Samples\mla01.manual_comb\MLA01_2018_T97.ply

# %%
import open3d as o3d
import numpy as np
from pathlib import Path
from collections import defaultdict
import os

# Define the directories
input_dir = Path('D:\CALI07\cali07_manclouds')
output_dir = Path('D:\CALI07\CALI_07_mancomb')

# Create output directory if not exists
output_dir.mkdir(parents=True, exist_ok=True)

# Group the files by their numbers
files_by_number = defaultdict(list)

for file in input_dir.glob('volume_noground_*.*.ply'):
    number = file.stem.split('_')[2].split('.')[0]  # Extract the {XXX} part
    files_by_number[number].append(file)

print(f'Found {len(files_by_number)} groups of files')

# Iterate over the grouped files
for number, files in files_by_number.items():
    if len(files) != 2:
        print(f"Skipping {number} as it does not have exactly 2 files")
        continue

    print(f'Processing files: {files[0].name}, {files[1].name}')

    # Sort files to ensure 'leaf' comes first, then 'wood'
    files = sorted(files, key=lambda x: x.stem.split('_')[2].split('.')[1])

    # Load the point clouds
    pcd1 = o3d.io.read_point_cloud(str(files[0]))
    pcd2 = o3d.io.read_point_cloud(str(files[1]))

    # Estimate the transformation for alignment with ICP
    max_correspondence_distance = 0.02  # This is a parameter you might need to adjust
    init = np.identity(4)
    transformation = o3d.pipelines.registration.registration_icp(
        pcd1, pcd2, max_correspondence_distance, init,
        o3d.pipelines.registration.TransformationEstimationPointToPoint()
    ).transformation

    # Apply the transformation to the second point cloud
    pcd2.transform(transformation)

    # Combine the point clouds
    pcd_combined = pcd1 + pcd2

    # Save the combined point cloud as a .ply file
    output_file = output_dir / f"volume_noground_{number}.ply"
    o3d.io.write_point_cloud(str(output_file), pcd_combined)

    print(f'Saved combined point cloud as: {output_file}')
# Out:
# Found 81 groups of files
# Processing files: volume_noground_100t1.leaf.ply, volume_noground_100t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_100t1.ply
# Processing files: volume_noground_102t1.leaf.ply, volume_noground_102t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_102t1.ply
# Processing files: volume_noground_103t1.leaf.ply, volume_noground_103t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_103t1.ply
# Processing files: volume_noground_104t1.leaf.ply, volume_noground_104t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_104t1.ply
# Processing files: volume_noground_105t1.leaf.ply, volume_noground_105t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_105t1.ply
# Processing files: volume_noground_107t1.leaf.ply, volume_noground_107t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_107t1.ply
# Processing files: volume_noground_107t2.leaf.ply, volume_noground_107t2.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_107t2.ply
# Processing files: volume_noground_107t3.leaf.ply, volume_noground_107t3.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_107t3.ply
# Processing files: volume_noground_108t1.leaf.ply, volume_noground_108t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_108t1.ply
# Processing files: volume_noground_108t2.leaf.ply, volume_noground_108t2.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_108t2.ply
# Processing files: volume_noground_109t1.leaf.ply, volume_noground_109t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_109t1.ply
# Processing files: volume_noground_109t2.leaf.ply, volume_noground_109t2.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_109t2.ply
# Processing files: volume_noground_109t3.leaf.ply, volume_noground_109t3.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_109t3.ply
# Processing files: volume_noground_10t1.leaf.ply, volume_noground_10t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_10t1.ply
# Processing files: volume_noground_110t1.leaf.ply, volume_noground_110t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_110t1.ply
# Processing files: volume_noground_111t1.leaf.ply, volume_noground_111t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_111t1.ply
# Processing files: volume_noground_112t1.leaf.ply, volume_noground_112t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_112t1.ply
# Processing files: volume_noground_113t1.leaf.ply, volume_noground_113t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_113t1.ply
# Processing files: volume_noground_14t1.leaf.ply, volume_noground_14t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_14t1.ply
# Processing files: volume_noground_16t1.leaf.ply, volume_noground_16t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_16t1.ply
# Processing files: volume_noground_16t2.leaf.ply, volume_noground_16t2.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_16t2.ply
# Processing files: volume_noground_16t3.leaf.ply, volume_noground_16t3.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_16t3.ply
# Processing files: volume_noground_17t1.leaf.ply, volume_noground_17t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_17t1.ply
# Processing files: volume_noground_18t1.leaf.ply, volume_noground_18t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_18t1.ply
# Processing files: volume_noground_1t1.leaf.ply, volume_noground_1t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_1t1.ply
# Processing files: volume_noground_2t1.leaf.ply, volume_noground_2t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_2t1.ply
# Processing files: volume_noground_2t2.leaf.ply, volume_noground_2t2.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_2t2.ply
# Processing files: volume_noground_30t1.leaf.ply, volume_noground_30t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_30t1.ply
# Processing files: volume_noground_31t1.leaf.ply, volume_noground_31t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_31t1.ply
# Processing files: volume_noground_34t1.leaf.ply, volume_noground_34t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_34t1.ply
# Processing files: volume_noground_36t1.leaf.ply, volume_noground_36t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_36t1.ply
# Processing files: volume_noground_38t1.leaf.ply, volume_noground_38t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_38t1.ply
# Processing files: volume_noground_3t1.leaf.ply, volume_noground_3t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_3t1.ply
# Processing files: volume_noground_40t1.leaf.ply, volume_noground_40t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_40t1.ply
# Processing files: volume_noground_41t1.leaf.ply, volume_noground_41t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_41t1.ply
# Processing files: volume_noground_42t1.leaf.ply, volume_noground_42t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_42t1.ply
# Processing files: volume_noground_43t1.leaf.ply, volume_noground_43t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_43t1.ply
# Processing files: volume_noground_44t1.leaf.ply, volume_noground_44t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_44t1.ply
# Processing files: volume_noground_45t1.leaf.ply, volume_noground_45t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_45t1.ply
# Processing files: volume_noground_46t1.leaf.ply, volume_noground_46t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_46t1.ply
# Processing files: volume_noground_47t1.leaf.ply, volume_noground_47t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_47t1.ply
# Processing files: volume_noground_48t1.leaf.ply, volume_noground_48t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_48t1.ply
# Processing files: volume_noground_49t1.leaf.ply, volume_noground_49t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_49t1.ply
# Processing files: volume_noground_4t1.leaf.ply, volume_noground_4t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_4t1.ply
# Processing files: volume_noground_50t1.leaf.ply, volume_noground_50t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_50t1.ply
# Processing files: volume_noground_51t1.leaf.ply, volume_noground_51t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_51t1.ply
# Processing files: volume_noground_53t1.leaf.ply, volume_noground_53t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_53t1.ply
# Processing files: volume_noground_54t1.leaf.ply, volume_noground_54t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_54t1.ply
# Processing files: volume_noground_55t1.leaf.ply, volume_noground_55t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_55t1.ply
# Processing files: volume_noground_56t1.leaf.ply, volume_noground_56t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_56t1.ply
# Processing files: volume_noground_57t1.leaf.ply, volume_noground_57t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_57t1.ply
# Processing files: volume_noground_59t1.leaf.ply, volume_noground_59t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_59t1.ply
# Processing files: volume_noground_60t1.leaf.ply, volume_noground_60t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_60t1.ply
# Processing files: volume_noground_62t1.leaf.ply, volume_noground_62t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_62t1.ply
# Processing files: volume_noground_64t1.leaf.ply, volume_noground_64t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_64t1.ply
# Processing files: volume_noground_67t1.leaf.ply, volume_noground_67t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_67t1.ply
# Processing files: volume_noground_68t1.leaf.ply, volume_noground_68t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_68t1.ply
# Processing files: volume_noground_6t1.leaf.ply, volume_noground_6t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_6t1.ply
# Processing files: volume_noground_71t1.leaf.ply, volume_noground_71t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_71t1.ply
# Processing files: volume_noground_72t1.leaf.ply, volume_noground_72t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_72t1.ply
# Processing files: volume_noground_73t1.leaf.ply, volume_noground_73t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_73t1.ply
# Processing files: volume_noground_75t1.leaf.ply, volume_noground_75t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_75t1.ply
# Processing files: volume_noground_76t1.leaf.ply, volume_noground_76t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_76t1.ply
# Processing files: volume_noground_77t1.leaf.ply, volume_noground_77t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_77t1.ply
# Processing files: volume_noground_79t1.leaf.ply, volume_noground_79t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_79t1.ply
# Processing files: volume_noground_7t1.leaf.ply, volume_noground_7t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_7t1.ply
# Processing files: volume_noground_80t1.leaf.ply, volume_noground_80t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_80t1.ply
# Processing files: volume_noground_80t2.leaf.ply, volume_noground_80t2.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_80t2.ply
# Processing files: volume_noground_81t1.leaf.ply, volume_noground_81t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_81t1.ply
# Processing files: volume_noground_82t1.leaf.ply, volume_noground_82t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_82t1.ply
# Processing files: volume_noground_83t1.leaf.ply, volume_noground_83t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_83t1.ply
# Processing files: volume_noground_86t1.leaf.ply, volume_noground_86t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_86t1.ply
# Processing files: volume_noground_8t1.leaf.ply, volume_noground_8t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_8t1.ply
# Processing files: volume_noground_8t2.leaf.ply, volume_noground_8t2.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_8t2.ply
# Processing files: volume_noground_90t1.leaf.ply, volume_noground_90t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_90t1.ply
# Processing files: volume_noground_92t1.leaf.ply, volume_noground_92t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_92t1.ply
# Processing files: volume_noground_94t1.leaf.ply, volume_noground_94t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_94t1.ply
# Processing files: volume_noground_95t1.leaf.ply, volume_noground_95t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_95t1.ply
# Processing files: volume_noground_96t1.leaf.ply, volume_noground_96t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_96t1.ply
# Processing files: volume_noground_99t1.leaf.ply, volume_noground_99t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_99t1.ply
# Processing files: volume_noground_9t1.leaf.ply, volume_noground_9t1.wood.ply
# Saved combined point cloud as: D:\CALI07\CALI_07_mancomb\volume_noground_9t1.ply
